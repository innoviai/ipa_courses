# %% [markdown]
# # Practice 5 - World Happiness Report

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Download the historical datafrom [the official website](https://worldhappiness.report/data/)
# * https://happiness-report.s3.amazonaws.com/2024/DataForTable2.1.xls

# %% [markdown]
# # Q1 - Read the file
# To begin, of course we need to load the excel file into our program first.
#
# **Hint**
# * Remember to import `pandas` first!
# * Use the `read_excel()` function to load the excel file

# %% [markdown]
# **Expecetd output**
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = None

# Your codes here



# Output
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2358     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2359     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2360     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2361     Zimbabwe  2022     3.296220            7.670073        0.666172
# 2362     Zimbabwe  2023     3.572386            7.678590        0.693817
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# # Q2 - Which years' data are in the dataset?
# A common question when we explore a dataset is "how much data are there?", besides looking for the number of rows and columns, we want to check the period covered.
#
#
# **Hint**
# *  Locate the `year` column using `df.loc`
# *  Convert that to a list using `to_list()` so that you can find the unique values using `set()` (alternatively you can use `drop_duplicates()`)
# *  Sort the years in ascending order before assigning into `year_list`
#
#
# **Expected output**
# *  The dataset spans across 19 years: [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
year_list = []

# Your codes here




# Output
print(f'The dataset spans across {len(year_list)} years: {year_list}')
# Out:
# The dataset spans across 19 years: [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %% [markdown]
# # Q3 - Find the subset of data corresponding to year 2023
#
# Looks like the latest data covered is 2023, let's locate that subset of data!
#
# **Hint**
# *  Construct the condition check for the `year` column
# *  Apply the filter using `df.loc`

# %% [markdown]
# **Expected output**
# ![image.png](data:image/png;base64,...)

# %%
df_2023 = None

# Your codes here



# Output
df_2023
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 14    Afghanistan  2023     1.445909                 NaN        0.368478
# 30        Albania  2023     5.444691            9.688706        0.690753
# 63      Argentina  2023     6.393229            9.993596        0.892118
# 80        Armenia  2023     5.679090            9.729613        0.819338
# 97      Australia  2023     7.024582           10.846434        0.896460
# ...           ...   ...          ...                 ...             ...
# 2295    Venezuela  2023     5.765363                 NaN        0.884668
# 2313      Vietnam  2023     6.325115            9.392351        0.844905
# 2327        Yemen  2023     3.531574                 NaN        0.824958
# 2344       Zambia  2023     3.685568            8.115053        0.664099
# 2362     Zimbabwe  2023     3.572386            7.678590        0.693817
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# # Q4 - Sort Year 2023 data according to descending order of `Life Ladder`

# %% [markdown]
# There are many metrics used in constructing the ranking. What if we just create a simple ranking using `Life Ladder`, i.e. "How happy are you"?
#
# **Hint**
# * Make use of `sort_values()` function provided by `df_2023` obtained in Q3

# %% [markdown]
# **Expected Result**
# ![image.png](data:image/png;base64,...)

# %%
df_2023_sorted = None

# Your codes here




# Output
df_2023_sorted
# Out:
#           Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 680            Finland  2023     7.698929           10.808451        0.946865
# 886            Iceland  2023     7.561609           10.934167        0.978789
# 556            Denmark  2023     7.504193           10.996293        0.915670
# 490         Costa Rica  2023     7.384069           10.020897        0.874572
# 1498       Netherlands  2023     7.254794           10.977064        0.914922
# ...                ...   ...          ...                 ...             ...
# 1835      Sierra Leone  2023     3.466578            7.411621        0.601414
# 472   Congo (Kinshasa)  2023     3.383398            7.075862        0.572275
# 258           Botswana  2023     3.331648            9.673302        0.701358
# 1277            Malawi  2023     3.272092            7.278899        0.469852
# 14         Afghanistan  2023     1.445909                 NaN        0.368478
#
# ...

# %% [markdown]
# # Q5 - Create a function to find the average `Social support` given a year
#
# **Hint**
# * Series objects support `.mean()` function to give you an average value (See below example)
#
# **Expected output**
# * In 2023, the average social support was 0.7910

# %%
# Hint
avg_ss = df.loc[:,'Social support'].mean()
print(f'Average social support across the whole dataset is {avg_ss:.4f}')
# Out:
# Average social support across the whole dataset is 0.8107

# %%
def average_social_support(year):
  # Your codes here
  return 0


# Output
print(f'In 2023, the average social support was {average_social_support(2023):.4f}')
# Out:
# In 2023, the average social support was 0.7910

# %% [markdown]
# # Q6 - Present the average social support for each year as a `pd.DataFrame`
#
# **Hint**
# *  Create a variable e.g. `support_data` to store a list of dictionary
# *  Write a loop through all the years (`year_list` from Q2)
# *  Reuse `average_social_support()` to calculate the value (from Q5)
# *  In each iteration, store `{'year': year, 'Average Social Support': value}` into `support_data`
# *  Create a `pd.DataFrame` with `support_data`

# %% [markdown]
# **Expected output**
#
# ![image.png](data:image/png;base64,...)

# %%
support_df = None
support_data = None

# Your codes here



# Output
support_df
# Out:
#     year  Average Social Support
# 0   2005                0.897367
# 1   2006                0.835852
# 2   2007                0.807694
# 3   2008                0.784401
# 4   2009                0.819076
# 5   2010                0.831849
# 6   2011                0.802802
# 7   2012                0.808637
# 8   2013                0.806087
# 9   2014                0.805678
# 10  2015                0.798260
# 11  2016                0.811967
# 12  2017                0.805164
# 13  2018                0.812160
# 14  2019                0.816875
# 15  2020                0.822982
# 16  2021                0.803933
# 17  2022                0.797777
# 18  2023                0.790988
