# %% [markdown]
# # Practice 4 - File processing with GOV.HK data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# DATA.GOV.HK is an initiative to make official data available to the public.
# Today we will explore a small dataset to practice file processing
# * https://data.gov.hk/en-data/dataset/hk-itib-itib02-itib-spending-data/resource/a2cc3e95-b044-4778-91ae-a2e9ff1a4d24

# %% [markdown]
# * Let's try to explore the file using basic Python.
# * Download: https://www.itib.gov.hk/en/spending/data/spending_data_of_head_135_en.csv
# * Upload the CSV file into this notebook (Click the file icon on the left)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Setting up

# %%
file_name = 'spending_data_of_head_135_en.csv'

# %% [markdown]
# ## Q1 - Load the file into a string
# *   csv files are usually plain-text files
# *   Open the file in read mode 'r'
# *   Load the content into `input_text` variable
#
#
# Expected:
# * Account,Expenditure Group,Subhead,Item, Actual($)
# * RECURRENT,PERSONNAL EMOLUMENTS,SALARIES                      ,* SALARIES                                ,151760978
# * RECURRENT,PERSONNAL EMOLUMENTS,ALLOWANCES                    ,OVERTIME                                ,507492
# * ...

# %%
input_text = ''

# TODO: Your code here


# Output
print(f'Data loaded:\n{input_text}')
# Out:
# Data loaded:
# Account,Expenditure Group,Subhead,Item,Actuals ($)
# RECURRENT,PERSONNAL EMOLUMENTS,SALARIES                      ,SALARIES                                ,39084027.67
# RECURRENT,PERSONNAL EMOLUMENTS,ALLOWANCES                    ,OVERTIME                                ,118091.92
# RECURRENT,PERSONNAL EMOLUMENTS,ALLOWANCES                    ,ACTING ALLOWANCES,1461406.45
# RECURRENT,PERSONNAL EMOLUMENTS,JOB-RELATED ALLOWANCES        ,RAIN STORM BLACK WARNING ALLOWANCE,624.02
# RECURRENT,PERSONNEL RELATED EXPENSES,MANDATORY PROVIDENT FUND CONTRIBUTION,CONTRIBUTION FOR RECRUITS UNDER THE NEW TERMS BEFORE CONFIRMATION,75394.23
# RECURRENT,PERSONNEL RELATED EXPENSES,CIVIL SERVICE PROVIDENT FUND CONTRIBUTION,MANDATORY CONTRIBUTION UNDER THE MANDATORY PROVIDENT FUND SCHEMES ORDINANCE,392782.38
# RECURRENT,PERSONNEL RELATED EXPENSES,CIVIL SERVICE PROVIDENT FUND CONTRIBUTION,GOVERNMENT VOLUNTARY CONTRIBUTION,2529445.09
# ...

# %% [markdown]
# ## Q2 - Split the data into a list of lines
#
# * Set `input_lines` to a list of rows using `splitlines()`
# * Set `line_count` to number of elements in `input_lines`
#
# Expected:
# *  "Number of lines loaded: 45"

# %%
input_lines = []
line_count = 0

# TODO: Your code here (Change input_lines and line_count)


# Output
print(f'Number of lines loaded: {line_count}')
# Out:
# Number of lines loaded: 45

# %% [markdown]
# ## Q3 - What are the column names?
# * The first line from `input_lines` is the header
# * The line is separated by comma (because it is a CSV)
# * `.split()` should help you cut that 1 long string into a list
# * [optional] If some columns have trailing spaces, you can remove them with `.strip()`
#
# Expected:
# * The columns are: `['Account', 'Expenditure Group', 'Subhead', 'Item', 'Actual($)']`

# %%
header_list = []

# TODO: Your code here (Change header_list)


# Output
print(f'The columns are: {header_list}')
# Out:
# The columns are: ['Account', 'Expenditure Group', 'Subhead', 'Item', 'Actuals ($)']

# %% [markdown]
# ## Q4 - Find out the sum of `Actual($)` values across all rows
# * Iterate through `input_lines` (after the first row)
# * Each iteration gives you a row and you need to split them by comma to find the columns
# * Split the line by comma to get a list of values
# * The final element of each row is the value (remember: `L[-1]` gives the last item from list `L`)
# * Convert the string format of the value into an float data type using `float()`
# * Sum up the values
#
# Expected:
# * Total value is: 96494942.43

# %%
value_sum = 0

# TODO: Your code here (change value_sum)



# Output
print(f'Total value is: {value_sum}')
# Out:
# Total value is: 564523667

# %% [markdown]
# # Q5 - Find out the sum of `Actual($)` only for `Expenditure Group`=`PERSONNEL RELATED EXPENSES`
#
# Hint:
# * Same as Q4 but add 1 check before incrementing `value_sum`
# * The `Expenditure Group` is the second column, you can also find this programatically using `header_list.index('Expenditure Group')`
#
# Expected:
# *  Total value is: 2997621.70

# %%
value_sum = 0

# TODO: Your code here (change value_sum)



# Output
print(f'Total value is: {value_sum}')
# Out:
# Total value is: 11269120
