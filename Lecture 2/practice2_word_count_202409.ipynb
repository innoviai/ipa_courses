# %% [markdown]
# # Practice 2 - Word Count

# %% [markdown]
# Write a program to show:
# 1.   number of characters ("Hello World!" => 12)
# 2.   number of words ("Hello World!" => 2)
# 3.   number of characters without white space ("Hello World!" => 11)
#
# Reference: https://charcounter.com/en/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# This is the input
input_text = '''The programme aims to impart the essential knowledge of process automation to students and equip them with automation techniques in the business. It adopts a contemporary project management approach to business process automation. It also examines the emerging business opportunities and challenges in its planning and implementation of process automation.'''

# %%
print(input_text)
# Out:
# The programme aims to impart the essential knowledge of process automation to students and equip them with automation techniques in the business. It adopts a contemporary project management approach to business process automation. It also examines the emerging business opportunities and challenges in its planning and implementation of process automation.

# %% [markdown]
# ## Q1 - Print the number of characters in `input_text`
#
# Expected result:
# *   Number of characters: 356

# %%
# Change this
q1_answer = 0


# Do not change this
print(f'Number of characters: {q1_answer}')
# Out:
# Number of characters: 0

# %% [markdown]
# ## Q2 - Print the number of words in `input_text`
# Hint:
# *   What separates each "word"?
# *   Is there a string function we can use to count that?
#
#
# Expected result:
# *   Expected: "Number of words: 50"

# %%
# Change this
q2_answer = 0


# Do not change this
print(f'Number of words: {q2_answer}')
# Out:
# Number of words: 0

# %% [markdown]
# ## Q3 - Print the number of characters without white spaces in `input_text`
#
# Expected result:
# *   "Number of characters without white space: 307"

# %%
# Change this
q3_answer = 0


# Do not change this
print(f'Number of characters without white space: {q3_answer}')
# Out:
# Number of characters without white space: 0
