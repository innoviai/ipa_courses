# %% [markdown]
# # Practice 1 - Market Capitalization Difference

# %% [markdown]
# In simple terms, market capitalization of a publicly traded company means how much it is work.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now given the shares and prices of 2 companies, show the below numbers up to 2 decimal points:
#
# 1.   Market cap of company 1 and Market cap of company 2
# 2.   Difference of the two

# %%
# This is the input
shares_1 = 1234
shares_2 = 5678
price_1 = 33.45
price_2 = 24.32

# %% [markdown]
# ## Q1 - Calculate the market cap of the 2 companies (Output is written for you)

# %% [markdown]
# Expected result:
# *   Market cap of company 1 is: 41277.3
# *   Market cap of company 2 is: 138088.96

# %%
# TODO: your code here
market_cap_1 = 0
market_cap_2 = 0

# Output (do not change this)
print(f'Market cap of company 1 is: {market_cap_1}')
print(f'Market cap of company 2 is: {market_cap_2}')
# Out:
# Market cap of company 1 is: 41277.3
# Market cap of company 2 is: 138088.96

# %% [markdown]
# ## Q2 - Print the market cap of the 2 companies with formatting (Commas as thouand separator with 2 decimal places)
#
# Expected result:
# *   Market cap of company 1 is: 41,277.30
# *   Market cap of company 2 is: 138,088.96

# %%
# TODO: your code here
print('...')
# Out:
# ...

# %% [markdown]
# ## Q3 - Print the absolute difference of the two market caps
#
# Expected result:
# *   Market cap difference is: 96,811.66

# %%
# TODO: your code here
print('...')
# Out:
# ...

# %% [markdown]
# # Q4 - Create a method to return the absolute difference of 2 numbers

# %% [markdown]
# * Create a method called `abs_diff()` which accepts 2 numbers and `return` the absolute difference of the 2 numbers
# * Use `abs_diff()` to reproduce the exact result as Q3
#
# Expected result:
# * Market cap difference is: 96,811.66

# %%
# Out:
# Market cap difference is: 96,811.66
